# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

facebook = pd.read_csv('DATA/dataset_Facebook.csv', delimiter=";", na_values = ['?'])

# %%
facebook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
facebook.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
facebook.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
facebook.shape
# Out:
# (500, 19)

# %%
facebook
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook = facebook[facebook.notna()]

# %%
facebook
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
facebook.head(
# Out:
#   File "<ipython-input-9-eee8c5d5ff2f>", line 1
#     facebook.head(
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
facebook = facebook[facebook.Paid.notna()]

# %%
facebook

# %%
facebook = facebook[facebook.like.notna()]

# %%
facebook

# %%
facebook = facebook[facebook.share.notna()]

# %%
facebook

# %%
facebook.info()

# %%
facebook['Category'].value_counts()

# %%
facebook.loc['Category'] = facebook['Category'].astype(float) #Changing non-accumulators to str

# %%
facebook.info()

# %%
facebook.loc['Post Month'] = facebook['Post Month'].astype(str)

# %%
facebook.loc['Post Weekday'] = facebook['Post Weekday'].astype(str)

# %%
facebook.info()

# %%
facebook.head()

# %%
facebook.columns #somehow the NaN values I thought I removed ended up in their own column at the end of the df.
                    #Can't figure out how to get rid of it.

# %%
numeric_vars = ['Page total likes', 'Paid',  'Lifetime Post Total Reach',
                                           'Lifetime Post Total Impressions',
                                                    'Lifetime Engaged Users',
                                                   'Lifetime Post Consumers',
                                                'Lifetime Post Consumptions',
              'Lifetime Post Impressions by people who have liked your Page',
                          'Lifetime Post reach by people who like your Page',
       'Lifetime People who have liked your Page and engaged with your post',
                                                                   'comment',
                                                                      'like',
                                                                     'share',
                                                        'Total Interactions']

# %%
categorical_vars['Type',
                                                                  'Category',
                                                                'Post Month',
                                                              'Post Weekday',
                                                                 'Post Hour']

# %%
categorical_vars = ['Type', 'Category', 'Post Month', 'Post Weekday', 'Post Hour']

# %%
ax = facebook[numeric_vars].hist #Yucky don't use

# %%
facebook[numeric_vars].plot(kind = 'box') #Yucky don't use

# %%
agg = facebook.groupby('Category').apply(len)
agg.plot(kind = 'bar').set_ylabel('Total Interactions')

# %%
facebook.columns

# %%
agg = facebook.groupby('Category').apply(len)
agg.plot(kind = 'bar').set_ylabel('Lifetime Post Total Reach')
# Out:
# Text(0, 0.5, 'Lifetime Post Total Reach')

# %%
agg = facebook.groupby('Category').apply(len)
agg.plot(kind = 'bar').set_ylabel('Lifetime Post Total Impressions')
# Out:
# Text(0, 0.5, 'Lifetime Post Total Impressions')

# %%
agg = facebook.groupby('Post Weekday').apply(len)
agg.plot(kind = 'bar').set_ylabel('Lifetime Post Total Impressions')

# %%
agg = facebook.groupby('Post Weekday').apply(len)
agg.plot(kind = 'bar').set_ylabel('Lifetime Post Total Reach')

# %%
sns.set(rc = {'figure.figsize': (11, 5)})
sns.set_style("ticks")
sns.set_context("talk")
ax = sns.scatterplot( x = 'Lifetime Post Total Reach', y = 'Lifetime Post Total Impressions', 
                     data = facebook, hue = "Lifetime Post Total Reach", size = "Lifetime Post Total Reach", marker = "p")

# %%
sns.barplot('Post Weekday','Lifetime Post Consumptions', data=facebook, ci=False, estimator=np.mean)
